# %%
# %load_ext autoreload
# %autoreload 2

# %%
from maze import Maze
from vizualiser import plot_maze
from game import run_game
from agent import RandomAgent

# %%
maze = Maze((5, 5), 3)

# %%
plot_maze(maze)

# %%
run_game(maze, RandomAgent(maze))

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

from agent import RandomAgent, SARSAAgent
from game import Game
from maze import Maze
from vizualiser import plot_cumsum, plot_maze, plot_rollav

# %% [markdown]
# ## Maze gen

# %%
maze = Maze((10, 10), 3)

# %% [markdown]
# ## Visualization

# %%
plot_maze(maze)

# %%
game = Game(maze, RandomAgent(maze), max_steps=20)

# %%
game.run_game(plot=True)
# Out:
# -20

# %%
game = Game(maze, RandomAgent(maze), max_steps=20)
game.train_agent(episodes=1000)
# Out:
# episodes: 100%|██████████| 1000/1000 [00:00<00:00, 1745.35it/s]

# %%
plot_cumsum(game)

# %% [markdown]
# ## SARSA agent

# %%
sarsaaagent = SARSAAgent(maze)

# %% [markdown]
# ### Train

# %%
game = Game(maze, sarsaaagent, max_steps=20)
game.train_agent(episodes=1000)
# Out:
# episodes: 100%|██████████| 1000/1000 [00:50<00:00, 19.98it/s]

# %% [markdown]
# ### Vizualization

# %% [markdown]
# #### Cumulative rewards

# %%
plot_cumsum(game)

# %% [markdown]
# #### Q Matrix

# %%
sarsaaagent.Q
# Out:
#                 0          1          2          3
# (0, 0)   0.000000 -19.396506   0.000000 -18.627565
# (0, 1) -18.228901 -18.968401   0.000000 -18.031582
# (0, 2) -18.178841 -19.138882   0.000000 -18.774648
# (0, 3) -19.248586 -20.589388   0.000000 -20.772734
# (0, 4) -21.690170 -21.772371   0.000000 -21.020676
# ...           ...        ...        ...        ...
# (9, 5) -10.834578 -16.280138 -16.785654   0.000000
# (9, 6) -15.001775 -18.369696 -17.906268   0.000000
# (9, 7) -17.497942 -18.040697 -18.409705   0.000000
# (9, 8) -16.243216 -15.963497 -16.961748   0.000000
# (9, 9) -16.822042   0.000000 -14.512806   0.000000
#
# [100 rows x 4 columns]

# %% [markdown]
# #### Rolling average

# %%
plot_rollav(game, w=10)

# %% [markdown]
# #### Sample run

# %%
game.run_game(plot=True)
# Out:
# -10
